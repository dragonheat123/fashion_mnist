# %% [markdown]
# <a href="https://colab.research.google.com/github/dragonheat123/fashion_mnist/blob/master/fashion_mnist_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing necessary libraries**

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

tf.__version__
# Out:
# '2.3.0'

# %% [markdown]
# **Loading in data for the fashion-MNIST dataset**

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# Checking the size and values of the data:

# %%
print(np.shape(train_images),np.shape(train_labels),np.shape(test_images),np.shape(test_labels))

print(np.min(train_images),np.max(train_images))
print(np.min(train_labels),np.max(train_labels))
print(np.min(test_images),np.max(test_images))
print(np.min(test_labels),np.max(test_labels))
# Out:
# (60000, 28, 28) (60000,) (10000, 28, 28) (10000,)
# 0 255
# 0 9
# 0 255
# 0 9

# %%
labels_text = ["T-Shirt/Top","Trouser","Pullover","Dress","Coat","Sandal","Shirt","Sneaker","Bag","Ankle boot"]


plt.figure(figsize=(50,5))
for i in range(0,10):
  plt.subplot(1,10,i+1)
  plt.title(str(train_labels[i]) + "-" + str(labels_text[train_labels[i]]))
  plt.imshow(train_images[i])
  plt.colorbar()

plt.figure(figsize=(50,5))
for i in range(10,20):
  plt.subplot(1,10,i-10+1)
  plt.title(str(train_labels[i]) + "-" + str(labels_text[train_labels[i]]))
  plt.imshow(train_images[i])
  plt.colorbar()

plt.figure(figsize=(50,5))
for i in range(1000,1010):
  plt.subplot(1,10,i-1000+1)
  plt.title(str(train_labels[i]) + "-" + str(labels_text[train_labels[i]]))
  plt.imshow(train_images[i])
  plt.colorbar()

plt.figure(figsize=(50,5))
for i in range(2000,2010):
  plt.subplot(1,10,i-2000+1)
  plt.title(str(train_labels[i]) + "-" + str(labels_text[train_labels[i]]))
  plt.imshow(train_images[i])
  plt.colorbar()

plt.figure(figsize=(50,5))
for i in range(5500,5510):
  plt.subplot(1,10,i-5500+1)
  plt.title(str(train_labels[i]) + "-" + str(labels_text[train_labels[i]]))
  plt.imshow(train_images[i])
  plt.colorbar()

# %% [markdown]
# Visually exploring the data.
# It seems like the images are well focused on the item, with straight and centered shots, and items are always the right side up.
#
# *   One thing to note is that there seem to be alot more tops and shoes compared to the rest of the other classes, so let's check the class distribution later
# *   The other thing is that the outline for each class of images is clear, but the interior grayscale intensity is changing -- > so we need to design within our CNN a component to deal with it (batch norm might help)
# *   The images seems to be well centered and seems to be the right way up all the time. So just in case, to account for images that might be flipped horizontally, and slightly rotated/translated, we perform image augmentation to the data used for training
# *   The images values will need to be rescale to 0-1 for more efficient learning

# %% [markdown]
# **Checking class distribution**

# %%
label_dist = list(train_labels)
label_dist = [str(x) for x in label_dist]
import pandas
from collections import Counter
letter_counts = Counter(label_dist)
df = pandas.DataFrame.from_dict(letter_counts, orient='index')
df.plot(kind='bar')

# %% [markdown]
# The class distribution seems to be even, which is a good sign. Otherwise we will have to do resampling to even out the classes, or customize the loss function of our model, to ensure learning is proper.

# %%
train_images_n = train_images/255
test_images_n = test_images/255

train_images_n = train_images_n.reshape(len(train_labels),28,28,1)
test_images_n = test_images_n.reshape(len(test_labels),28,28,1)

#####splitting training set into a train set and validation set for image augmentation
from sklearn.model_selection import train_test_split
train_images_a, val_images_a, train_labels_a, val_labels_a = train_test_split(train_images_n, train_labels, test_size=0.2, random_state=1)

# %% [markdown]
# We normalize the images and then we split the training set into train and validation set for image augmentation.

# %% [markdown]
# **Augmenting the dataset with horizontal flips | +-5% translation | +-5 deg rotations | [0.95-1.05] zoom**

# %%
from keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator

train_transformations = ImageDataGenerator(
        rotation_range=5,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=0.05,
        zoom_range=0.05,
        horizontal_flip=True,
        fill_mode='nearest')

vis_generator = train_transformations.flow(train_images_n,train_labels,batch_size=1)
train_generator = train_transformations.flow(train_images_a,train_labels_a,batch_size=512)
val_generator = train_transformations.flow(val_images_a,val_labels_a,batch_size=512)


######visualization of the augmentations
plt.figure(figsize=(50,5))
for i in range(0,10):
  v = vis_generator.next()
  img = v[0][0].reshape([28,28])
  plt.subplot(1,10,i+1)
  plt.title(str(v[1][0]) + "-" + str(labels_text[v[1][0]]))
  plt.imshow(img)
  plt.colorbar()

# %% [markdown]
# Image augmentation for the training data helps the CNN model to become more resillent to image rotation, tranlation, zooming, and shear effects that could affect an input image

# %% [markdown]
# **CNN Design**

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, AveragePooling2D, Concatenate, BatchNormalization, Dropout
from keras.callbacks import EarlyStopping

input_layer = keras.Input(shape=(28,28,1))
bn = BatchNormalization()(input_layer)                                          #batch normalization to prevent the network from being fixated on a certain feature, by keeping the weights of the network from going too extreme
conv1 = Conv2D(filters=128,kernel_size=3,activation='relu')(bn)                 #large number of initial (3x3) filter to gather features for the model
do_1 = keras.layers.Dropout(0.1)(conv1)                                         #dropout between image layers to prevent overfitting to the training dataset
conv2 = Conv2D(filters=64,kernel_size=3,activation='relu')(do_1)                #second layer of filter to obtain higher level features
mp1 = MaxPooling2D(pool_size=(3,3))(conv2)                                      #combine both maxpooling + averagepooling to capture both sharp features (especially the edge of the images) and smooth out softer features (like logos in shirt)
ap1 = AveragePooling2D(pool_size=(3,3))(conv2)
conc = Concatenate()([mp1,ap1])
flat1 = Flatten()(conc)                                                         #convert output of filters into single feature vector
do_2 = keras.layers.Dropout(0.1)(flat1)                                         #again dropout to prevent overfitting
dense1 = Dense(128,activation='relu')(do_2)                                     #dense layer to evaluate the feature vector and obtain accurate feature representation
output_layer = Dense(10, activation='softmax')(dense1)                          #softmax for output for catergorical classification

model = keras.Model(inputs=input_layer, outputs=output_layer)
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 28, 28, 1)    4           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 26, 26, 128)  1280        batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 26, 26, 128)  0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 24, 24, 64)   73792       dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 8, 8, 64)     0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 8, 8, 64)     0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 128)    0           max_pooling2d[0][0]
#                                                                  average_pooling2d[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8192)         0           concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8192)         0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1048704     dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           1290        dense[0][0]
# ==================================================================================================
# Total params: 1,125,070
# Trainable params: 1,125,068
# Non-trainable params: 2
# __________________________________________________________________________________________________

# %%
### using sparsecategoricalcrossentropy loss because labels are not one-hot encoded but are integers instead (onehot uses categorical loss)  

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
### using early stopping to stop the training once the validation accuracy plateau, to ensure that the model will not be overfitting, 
es = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=20, restore_best_weights=True)

# %%
### since the imagedatagenerator shuffles samples when outputting batches, the model is sort of cross-validated
### small batch-size so model will gradients gradually and learn according to the features of each batch
history = model.fit(train_generator,validation_data=val_generator, epochs=300, callbacks=[es], batch_size=512, shuffle=True)
# Out:
# Epoch 1/300
# 94/94 [==============================] - 26s 281ms/step - loss: 1.9144 - accuracy: 0.5457 - val_loss: 1.8961 - val_accuracy: 0.5777
# Epoch 2/300
# 94/94 [==============================] - 26s 272ms/step - loss: 1.8026 - accuracy: 0.6583 - val_loss: 1.7727 - val_accuracy: 0.6984
# Epoch 3/300
# 94/94 [==============================] - 25s 268ms/step - loss: 1.6437 - accuracy: 0.8185 - val_loss: 1.6270 - val_accuracy: 0.8352
# Epoch 4/300
# 94/94 [==============================] - 25s 269ms/step - loss: 1.6205 - accuracy: 0.8414 - val_loss: 1.6141 - val_accuracy: 0.8470
# Epoch 5/300
# 94/94 [==============================] - 25s 268ms/step - loss: 1.6059 - accuracy: 0.8564 - val_loss: 1.6045 - val_accuracy: 0.8557
# Epoch 6/300
# 94/94 [==============================] - 25s 269ms/step - loss: 1.6034 - accuracy: 0.8580 - val_loss: 1.6021 - val_accuracy: 0.8612
# Epoch 7/300
# 94/94 [==============================] - 25s 268ms/step - loss: 1.5968 - accuracy: 0.8646 - val_loss: 1.6010 - val_accuracy: 0.8602
# Epoch 8/300
# 94/94 [==============================] - 25s 269ms/step - loss: 1.5912 - accuracy: 0.8705 - val_loss: 1.5893 - val_accuracy: 0.8708
# Epoch 9/300
# 94/94 [==============================] - 25s 269ms/step - loss: 1.5878 - accuracy: 0.8738 - val_loss: 1.5950 - val_accuracy: 0.8663
# Epoch 10/300
# 94/94 [==============================] - 25s 268ms/step - loss: 1.5853 - accuracy: 0.8761 - val_loss: 1.5824 - val_accuracy: 0.8788
# Epoch 11/300
# 94/94 [==============================] - 25s 269ms/step - loss: 1.5833 - accuracy: 0.8778 - val_loss: 1.5837 - val_accuracy: 0.8778
# Epoch 12/300
# 94/94 [==============================] - 26s 271ms/step - loss: 1.5792 - accuracy: 0.8820 - val_loss: 1.5802 - val_accuracy: 0.8804
# Epoch 13/300
# 94/94 [==============================] - 25s 268ms/step - loss: 1.5740 - accuracy: 0.8877 - val_loss: 1.5767 - val_accuracy: 0.8842
# Epoch 14/300
# 94/94 [==============================] - 26s 273ms/step - loss: 1.5709 - accuracy: 0.8903 - val_loss: 1.5712 - val_accuracy: 0.8894
# Epoch 15/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5703 - accuracy: 0.8911 - val_loss: 1.5703 - val_accuracy: 0.8908
# Epoch 16/300
# 94/94 [==============================] - 26s 273ms/step - loss: 1.5683 - accuracy: 0.8930 - val_loss: 1.5683 - val_accuracy: 0.8931
# Epoch 17/300
# 94/94 [==============================] - 26s 272ms/step - loss: 1.5658 - accuracy: 0.8954 - val_loss: 1.5750 - val_accuracy: 0.8867
# Epoch 18/300
# 94/94 [==============================] - 26s 271ms/step - loss: 1.5676 - accuracy: 0.8934 - val_loss: 1.5677 - val_accuracy: 0.8933
# Epoch 19/300
# 94/94 [==============================] - 25s 268ms/step - loss: 1.5615 - accuracy: 0.9001 - val_loss: 1.5689 - val_accuracy: 0.8923
# Epoch 20/300
# 94/94 [==============================] - 25s 271ms/step - loss: 1.5624 - accuracy: 0.8987 - val_loss: 1.5620 - val_accuracy: 0.8995
# Epoch 21/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5617 - accuracy: 0.8999 - val_loss: 1.5634 - val_accuracy: 0.8975
# Epoch 22/300
# 94/94 [==============================] - 26s 271ms/step - loss: 1.5580 - accuracy: 0.9028 - val_loss: 1.5633 - val_accuracy: 0.8982
# Epoch 23/300
# 94/94 [==============================] - 25s 269ms/step - loss: 1.5578 - accuracy: 0.9039 - val_loss: 1.5681 - val_accuracy: 0.8930
# Epoch 24/300
# 94/94 [==============================] - 26s 272ms/step - loss: 1.5556 - accuracy: 0.9057 - val_loss: 1.5605 - val_accuracy: 0.9001
# Epoch 25/300
# 94/94 [==============================] - 25s 271ms/step - loss: 1.5565 - accuracy: 0.9045 - val_loss: 1.5631 - val_accuracy: 0.8973
# Epoch 26/300
# 94/94 [==============================] - 26s 273ms/step - loss: 1.5520 - accuracy: 0.9099 - val_loss: 1.5585 - val_accuracy: 0.9018
# Epoch 27/300
# 94/94 [==============================] - 25s 269ms/step - loss: 1.5529 - accuracy: 0.9081 - val_loss: 1.5575 - val_accuracy: 0.9041
# Epoch 28/300
# 94/94 [==============================] - 25s 267ms/step - loss: 1.5518 - accuracy: 0.9095 - val_loss: 1.5623 - val_accuracy: 0.8979
# Epoch 29/300
# 94/94 [==============================] - 25s 271ms/step - loss: 1.5514 - accuracy: 0.9097 - val_loss: 1.5551 - val_accuracy: 0.9062
# Epoch 30/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5489 - accuracy: 0.9124 - val_loss: 1.5551 - val_accuracy: 0.9059
# Epoch 31/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5479 - accuracy: 0.9134 - val_loss: 1.5580 - val_accuracy: 0.9027
# Epoch 32/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5488 - accuracy: 0.9120 - val_loss: 1.5550 - val_accuracy: 0.9062
# Epoch 33/300
# 94/94 [==============================] - 25s 268ms/step - loss: 1.5469 - accuracy: 0.9146 - val_loss: 1.5538 - val_accuracy: 0.9075
# Epoch 34/300
# 94/94 [==============================] - 25s 271ms/step - loss: 1.5476 - accuracy: 0.9138 - val_loss: 1.5562 - val_accuracy: 0.9045
# Epoch 35/300
# 94/94 [==============================] - 25s 269ms/step - loss: 1.5460 - accuracy: 0.9150 - val_loss: 1.5518 - val_accuracy: 0.9102
# Epoch 36/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5462 - accuracy: 0.9151 - val_loss: 1.5508 - val_accuracy: 0.9103
# Epoch 37/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5404 - accuracy: 0.9212 - val_loss: 1.5548 - val_accuracy: 0.9062
# Epoch 38/300
# 94/94 [==============================] - 25s 271ms/step - loss: 1.5436 - accuracy: 0.9175 - val_loss: 1.5510 - val_accuracy: 0.9093
# Epoch 39/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5428 - accuracy: 0.9186 - val_loss: 1.5525 - val_accuracy: 0.9090
# Epoch 40/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5420 - accuracy: 0.9194 - val_loss: 1.5548 - val_accuracy: 0.9056
# Epoch 41/300
# 94/94 [==============================] - 25s 268ms/step - loss: 1.5431 - accuracy: 0.9185 - val_loss: 1.5530 - val_accuracy: 0.9087
# Epoch 42/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5422 - accuracy: 0.9189 - val_loss: 1.5534 - val_accuracy: 0.9076
# Epoch 43/300
# 94/94 [==============================] - 25s 268ms/step - loss: 1.5419 - accuracy: 0.9192 - val_loss: 1.5506 - val_accuracy: 0.9111
# Epoch 44/300
# 94/94 [==============================] - 25s 269ms/step - loss: 1.5385 - accuracy: 0.9226 - val_loss: 1.5479 - val_accuracy: 0.9127
# Epoch 45/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5381 - accuracy: 0.9229 - val_loss: 1.5513 - val_accuracy: 0.9097
# Epoch 46/300
# 94/94 [==============================] - 25s 268ms/step - loss: 1.5391 - accuracy: 0.9220 - val_loss: 1.5502 - val_accuracy: 0.9101
# Epoch 47/300
# 94/94 [==============================] - 26s 271ms/step - loss: 1.5409 - accuracy: 0.9199 - val_loss: 1.5492 - val_accuracy: 0.9125
# Epoch 48/300
# 94/94 [==============================] - 25s 269ms/step - loss: 1.5373 - accuracy: 0.9239 - val_loss: 1.5547 - val_accuracy: 0.9062
# Epoch 49/300
# 94/94 [==============================] - 25s 271ms/step - loss: 1.5385 - accuracy: 0.9224 - val_loss: 1.5478 - val_accuracy: 0.9123
# Epoch 50/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5360 - accuracy: 0.9253 - val_loss: 1.5483 - val_accuracy: 0.9115
# Epoch 51/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5361 - accuracy: 0.9245 - val_loss: 1.5501 - val_accuracy: 0.9110
# Epoch 52/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5363 - accuracy: 0.9248 - val_loss: 1.5493 - val_accuracy: 0.9117
# Epoch 53/300
# 94/94 [==============================] - 25s 269ms/step - loss: 1.5357 - accuracy: 0.9254 - val_loss: 1.5480 - val_accuracy: 0.9121
# Epoch 54/300
# 94/94 [==============================] - 25s 271ms/step - loss: 1.5380 - accuracy: 0.9230 - val_loss: 1.5491 - val_accuracy: 0.9123
# Epoch 55/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5341 - accuracy: 0.9270 - val_loss: 1.5464 - val_accuracy: 0.9143
# Epoch 56/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5346 - accuracy: 0.9264 - val_loss: 1.5494 - val_accuracy: 0.9112
# Epoch 57/300
# 94/94 [==============================] - 25s 268ms/step - loss: 1.5343 - accuracy: 0.9260 - val_loss: 1.5455 - val_accuracy: 0.9158
# Epoch 58/300
# 94/94 [==============================] - 25s 268ms/step - loss: 1.5341 - accuracy: 0.9271 - val_loss: 1.5468 - val_accuracy: 0.9145
# Epoch 59/300
# 94/94 [==============================] - 25s 266ms/step - loss: 1.5344 - accuracy: 0.9264 - val_loss: 1.5448 - val_accuracy: 0.9156
# Epoch 60/300
# 94/94 [==============================] - 25s 267ms/step - loss: 1.5329 - accuracy: 0.9280 - val_loss: 1.5488 - val_accuracy: 0.9125
# Epoch 61/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5323 - accuracy: 0.9289 - val_loss: 1.5450 - val_accuracy: 0.9155
# Epoch 62/300
# 94/94 [==============================] - 25s 271ms/step - loss: 1.5324 - accuracy: 0.9287 - val_loss: 1.5441 - val_accuracy: 0.9175
# Epoch 63/300
# 94/94 [==============================] - 25s 269ms/step - loss: 1.5328 - accuracy: 0.9282 - val_loss: 1.5421 - val_accuracy: 0.9186
# Epoch 64/300
# 94/94 [==============================] - 25s 268ms/step - loss: 1.5318 - accuracy: 0.9291 - val_loss: 1.5424 - val_accuracy: 0.9180
# Epoch 65/300
# 94/94 [==============================] - 25s 268ms/step - loss: 1.5302 - accuracy: 0.9307 - val_loss: 1.5432 - val_accuracy: 0.9176
# Epoch 66/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5321 - accuracy: 0.9289 - val_loss: 1.5439 - val_accuracy: 0.9175
# Epoch 67/300
# 94/94 [==============================] - 25s 269ms/step - loss: 1.5305 - accuracy: 0.9308 - val_loss: 1.5499 - val_accuracy: 0.9111
# Epoch 68/300
# 94/94 [==============================] - 25s 268ms/step - loss: 1.5290 - accuracy: 0.9320 - val_loss: 1.5432 - val_accuracy: 0.9175
# Epoch 69/300
# 94/94 [==============================] - 25s 268ms/step - loss: 1.5294 - accuracy: 0.9315 - val_loss: 1.5501 - val_accuracy: 0.9107
# Epoch 70/300
# 94/94 [==============================] - 25s 269ms/step - loss: 1.5295 - accuracy: 0.9317 - val_loss: 1.5474 - val_accuracy: 0.9136
# Epoch 71/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5311 - accuracy: 0.9294 - val_loss: 1.5485 - val_accuracy: 0.9125
# Epoch 72/300
# 94/94 [==============================] - 25s 268ms/step - loss: 1.5295 - accuracy: 0.9317 - val_loss: 1.5428 - val_accuracy: 0.9180
# Epoch 73/300
# 94/94 [==============================] - 25s 269ms/step - loss: 1.5287 - accuracy: 0.9325 - val_loss: 1.5477 - val_accuracy: 0.9122
# Epoch 74/300
# 94/94 [==============================] - 26s 272ms/step - loss: 1.5290 - accuracy: 0.9324 - val_loss: 1.5471 - val_accuracy: 0.9134
# Epoch 75/300
# 94/94 [==============================] - 25s 269ms/step - loss: 1.5305 - accuracy: 0.9308 - val_loss: 1.5418 - val_accuracy: 0.9180
# Epoch 76/300
# 94/94 [==============================] - 25s 267ms/step - loss: 1.5280 - accuracy: 0.9326 - val_loss: 1.5445 - val_accuracy: 0.9164
# Epoch 77/300
# 94/94 [==============================] - 25s 267ms/step - loss: 1.5290 - accuracy: 0.9322 - val_loss: 1.5454 - val_accuracy: 0.9153
# Epoch 78/300
# 94/94 [==============================] - 25s 267ms/step - loss: 1.5289 - accuracy: 0.9324 - val_loss: 1.5437 - val_accuracy: 0.9172
# Epoch 79/300
# 94/94 [==============================] - 25s 268ms/step - loss: 1.5292 - accuracy: 0.9317 - val_loss: 1.5448 - val_accuracy: 0.9170
# Epoch 80/300
# 94/94 [==============================] - 25s 269ms/step - loss: 1.5285 - accuracy: 0.9324 - val_loss: 1.5444 - val_accuracy: 0.9172
# Epoch 81/300
# 94/94 [==============================] - 25s 270ms/step - loss: 1.5282 - accuracy: 0.9329 - val_loss: 1.5438 - val_accuracy: 0.9168
# Epoch 82/300
# 94/94 [==============================] - 25s 268ms/step - loss: 1.5255 - accuracy: 0.9357 - val_loss: 1.5485 - val_accuracy: 0.9118
# Epoch 83/300
# 94/94 [==============================] - ETA: 0s - loss: 1.5267 - accuracy: 0.9341Restoring model weights from the end of the best epoch.
# 94/94 [==============================] - 26s 271ms/step - loss: 1.5267 - accuracy: 0.9341 - val_loss: 1.5430 - val_accuracy: 0.9174
# Epoch 00083: early stopping

# %%
plt.figure(3)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')

# %% [markdown]
# **Testing Accuracy**

# %%
test_loss, test_acc = model.evaluate(test_images_n,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 2s - loss: 1.5392 - accuracy: 0.9217
#
# Test accuracy: 0.9217000007629395

# %% [markdown]
# **Error Analysis and Future Improvements**

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels,np.argmax(model.predict(test_images_n),axis=1))

true_labels = [labels_text[x] for x in test_labels]
predicted_labels = [labels_text[x] for x in np.argmax(model.predict(test_images_n),axis=1)]

import seaborn as sns
plt.figure(figsize=(8,6))
sns.heatmap(cm, xticklabels=labels_text, yticklabels=labels_text, cmap='binary',annot=True)
plt.ylabel('true')
plt.xlabel('pred')
# Out:
# Text(0.5, 33.0, 'pred')

# %% [markdown]
# The most common error is to mistake a shirt for a top and vice versa, and most errors are symmetrical. However, a perculiar one way error is to mistake a ankle-boot for a sneaker. Let's check out some images for the errors.

# %%
labels_text
# Out:
# ['T-Shirt/Top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
ind = list(set(np.where(np.array(true_labels)=="Ankle boot")[0].tolist()).intersection(np.where(np.array(predicted_labels)=="Sneaker")[0].tolist()))
plt.figure(figsize=(25,5))
for i in range(0,5):
  plt.subplot(1,5,i+1)
  plt.imshow(test_images[ind[i]])
  plt.title("Ankle Boot but pred Sneaker")


ind = list(set(np.where(np.array(true_labels)=="Shirt")[0].tolist()).intersection(np.where(np.array(predicted_labels)=="T-Shirt/Top")[0].tolist()))
plt.figure(figsize=(25,5))
for i in range(0,5):
  plt.subplot(1,5,i+1)
  plt.imshow(test_images[ind[i]])
  plt.title("Shirt but pred T-Shirt/Top")


ind = list(set(np.where(np.array(true_labels)=="Pullover")[0].tolist()).intersection(np.where(np.array(predicted_labels)=="Coat")[0].tolist()))
plt.figure(figsize=(25,5))
for i in range(0,5):
  plt.subplot(1,5,i+1)
  plt.imshow(test_images[ind[i]])
  plt.title("Pullover but pred Coat")

# %% [markdown]
# *    Some of these error pictures are really ambigous, not sure if a human will also classify it correctly. (e.g. I would kind of argue against the true labels for the 2nd, 4th and 5th picture for shirt)
#
# *    Seems like the pictures in the test set are also focused nicely. In this case the image augmentation might add addtional noise that might distort the accuracy of the model, and might not be worth it to perform augmentation since it adds additional processing and training time. Some other augmentation methods could be tried out like random erasing of pixels. But the augmentation parameters will have carefully tuned to ensure there is minimal noise within the training data.
#
# *    For future models, bayesian opt can be used to find the better hyperparameters that includes the number of filters, size of the the filters, dropout ratio and number of neurouns in the dense layer.
#
# *    Also deeper convolutional networks architectures like ResNet with skip connections could be used to pick out more advanced features of classification.
#
# *    Hyperparameters optimization and increasing the depth of the network can have diminishing returns on the accuracy vs training complexity.
