# %% [markdown]
# <a href="https://colab.research.google.com/github/dragonheat123/fashion_mnist/blob/master/testing_just_maxpool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing necessary libraries**

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

tf.__version__
# Out:
# '2.3.0'

# %% [markdown]
# **Loading in data for the fashion-MNIST dataset**

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# Checking the size and values of the data:

# %%
print(np.shape(train_images),np.shape(train_labels),np.shape(test_images),np.shape(test_labels))

print(np.min(train_images),np.max(train_images))
print(np.min(train_labels),np.max(train_labels))
print(np.min(test_images),np.max(test_images))
print(np.min(test_labels),np.max(test_labels))
# Out:
# (60000, 28, 28) (60000,) (10000, 28, 28) (10000,)
# 0 255
# 0 9
# 0 255
# 0 9

# %%
labels_text = ["T-Shirt/Top","Trouser","Pullover","Dress","Coat","Sandal","Shirt","Sneaker","Bag","Ankle boot"]


plt.figure(figsize=(50,5))
for i in range(0,10):
  plt.subplot(1,10,i+1)
  plt.title(str(train_labels[i]) + "-" + str(labels_text[train_labels[i]]))
  plt.imshow(train_images[i])
  plt.colorbar()

plt.figure(figsize=(50,5))
for i in range(10,20):
  plt.subplot(1,10,i-10+1)
  plt.title(str(train_labels[i]) + "-" + str(labels_text[train_labels[i]]))
  plt.imshow(train_images[i])
  plt.colorbar()

plt.figure(figsize=(50,5))
for i in range(1000,1010):
  plt.subplot(1,10,i-1000+1)
  plt.title(str(train_labels[i]) + "-" + str(labels_text[train_labels[i]]))
  plt.imshow(train_images[i])
  plt.colorbar()

plt.figure(figsize=(50,5))
for i in range(2000,2010):
  plt.subplot(1,10,i-2000+1)
  plt.title(str(train_labels[i]) + "-" + str(labels_text[train_labels[i]]))
  plt.imshow(train_images[i])
  plt.colorbar()

plt.figure(figsize=(50,5))
for i in range(5500,5510):
  plt.subplot(1,10,i-5500+1)
  plt.title(str(train_labels[i]) + "-" + str(labels_text[train_labels[i]]))
  plt.imshow(train_images[i])
  plt.colorbar()

# %% [markdown]
# Visually exploring the data.
# It seems like the images are well focused on the item, with straight and centered shots, and items are always the right side up.
#
# *   One thing to note is that there seem to be alot more tops and shoes compared to the rest of the other classes, so let's check the class distribution later
# *   The other thing is that the outline for each class of images is clear, but the interior grayscale intensity is changing -- > so we need to design within our CNN a component to deal with it (batch norm might help)
# *   The images seems to be well centered and seems to be the right way up all the time. So just in case, to account for images that might be flipped horizontally, and slightly rotated/translated, we perform image augmentation to the data used for training
# *   The images values will need to be rescale to 0-1 for more efficient learning

# %% [markdown]
# **Checking class distribution**

# %%
label_dist = list(train_labels)
label_dist = [str(x) for x in label_dist]
import pandas
from collections import Counter
letter_counts = Counter(label_dist)
df = pandas.DataFrame.from_dict(letter_counts, orient='index')
df.plot(kind='bar')

# %% [markdown]
# The class distribution seems to be even, which is a good sign. Otherwise we will have to do resampling to even out the classes, or customize the loss function of our model, to ensure learning is proper.

# %%
train_images_n = train_images/255
test_images_n = test_images/255

train_images_n = train_images_n.reshape(len(train_labels),28,28,1)
test_images_n = test_images_n.reshape(len(test_labels),28,28,1)

#####splitting training set into a train set and validation set for image augmentation
from sklearn.model_selection import train_test_split
train_images_a, val_images_a, train_labels_a, val_labels_a = train_test_split(train_images_n, train_labels, test_size=0.2, random_state=1)

# %% [markdown]
# We normalize the images and then we split the training set into train and validation set for image augmentation.

# %% [markdown]
# **Augmenting the dataset with horizontal flips | +-5% translation | +-5 deg rotations | [0.95-1.05] zoom**

# %%
from keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator

train_transformations = ImageDataGenerator(
        rotation_range=5,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=0.05,
        zoom_range=0.05,
        horizontal_flip=True,
        fill_mode='nearest')

vis_generator = train_transformations.flow(train_images_n,train_labels,batch_size=1)
train_generator = train_transformations.flow(train_images_a,train_labels_a,batch_size=512)
val_generator = train_transformations.flow(val_images_a,val_labels_a,batch_size=512)


######visualization of the augmentations
plt.figure(figsize=(50,5))
for i in range(0,10):
  v = vis_generator.next()
  img = v[0][0].reshape([28,28])
  plt.subplot(1,10,i+1)
  plt.title(str(v[1][0]) + "-" + str(labels_text[v[1][0]]))
  plt.imshow(img)
  plt.colorbar()

# %% [markdown]
# Image augmentation for the training data helps the CNN model to become more resillent to image rotation, tranlation, zooming, and shear effects that could affect an input image

# %% [markdown]
# **CNN Design**

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, AveragePooling2D, Concatenate, BatchNormalization, Dropout
from keras.callbacks import EarlyStopping

input_layer = keras.Input(shape=(28,28,1))
bn = BatchNormalization()(input_layer)                                          #batch normalization to prevent the network from being fixated on a certain feature, by keeping the weights of the network from going too extreme
conv1 = Conv2D(filters=128,kernel_size=3,activation='relu')(bn)                 #large number of initial (3x3) filter to gather features for the model
do_1 = keras.layers.Dropout(0.1)(conv1)                                         #dropout between image layers to prevent overfitting to the training dataset
conv2 = Conv2D(filters=64,kernel_size=3,activation='relu')(do_1)                #second layer of filter to obtain higher level features
mp1 = MaxPooling2D(pool_size=(3,3))(conv2)                                      #combine both maxpooling + averagepooling to capture both sharp features (especially the edge of the images) and smooth out softer features (like logos in shirt)
ap1 = AveragePooling2D(pool_size=(3,3))(conv2)
conc = Concatenate()([mp1,ap1])
flat1 = Flatten()(conc)                                                         #convert output of filters into single feature vector
do_2 = keras.layers.Dropout(0.1)(flat1)                                         #again dropout to prevent overfitting
dense1 = Dense(128,activation='relu')(do_2)                                     #dense layer to evaluate the feature vector and obtain accurate feature representation
output_layer = Dense(10, activation='softmax')(dense1)                          #softmax for output for catergorical classification

model = keras.Model(inputs=input_layer, outputs=output_layer)
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 28, 28, 1)    4           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 26, 26, 128)  1280        batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 26, 26, 128)  0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 24, 24, 64)   73792       dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 8, 8, 64)     0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 8, 8, 64)     0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 128)    0           max_pooling2d[0][0]
#                                                                  average_pooling2d[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8192)         0           concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8192)         0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1048704     dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           1290        dense[0][0]
# ==================================================================================================
# Total params: 1,125,070
# Trainable params: 1,125,068
# Non-trainable params: 2
# __________________________________________________________________________________________________

# %%
### using sparsecategoricalcrossentropy loss because labels are not one-hot encoded but are integers instead (onehot uses categorical loss)  

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
### using early stopping to stop the training once the validation accuracy plateau, to ensure that the model will not be overfitting, 
es = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=25, restore_best_weights=True)

# %%
### since the imagedatagenerator shuffles samples when outputting batches, the model is sort of cross-validated
### small batch-size so model will gradients gradually and learn according to the features of each batch
history = model.fit(train_generator,validation_data=val_generator, epochs=300, callbacks=[es], batch_size=512, shuffle=True)
# Out:
# Epoch 1/300
# 94/94 [==============================] - 24s 253ms/step - loss: 1.7839 - accuracy: 0.6791 - val_loss: 1.7436 - val_accuracy: 0.7354
# Epoch 2/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.6826 - accuracy: 0.7793 - val_loss: 1.7073 - val_accuracy: 0.7601
# Epoch 3/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.6637 - accuracy: 0.7984 - val_loss: 1.6549 - val_accuracy: 0.8076
# Epoch 4/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.6335 - accuracy: 0.8273 - val_loss: 1.6201 - val_accuracy: 0.8423
# Epoch 5/300
# 94/94 [==============================] - 23s 240ms/step - loss: 1.6144 - accuracy: 0.8475 - val_loss: 1.6131 - val_accuracy: 0.8484
# Epoch 6/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.6077 - accuracy: 0.8541 - val_loss: 1.6058 - val_accuracy: 0.8559
# Epoch 7/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.6016 - accuracy: 0.8599 - val_loss: 1.5960 - val_accuracy: 0.8660
# Epoch 8/300
# 94/94 [==============================] - 23s 241ms/step - loss: 1.5933 - accuracy: 0.8678 - val_loss: 1.5944 - val_accuracy: 0.8668
# Epoch 9/300
# 94/94 [==============================] - 23s 241ms/step - loss: 1.5878 - accuracy: 0.8741 - val_loss: 1.5928 - val_accuracy: 0.8679
# Epoch 10/300
# 94/94 [==============================] - 23s 240ms/step - loss: 1.5834 - accuracy: 0.8787 - val_loss: 1.5803 - val_accuracy: 0.8809
# Epoch 11/300
# 94/94 [==============================] - 22s 239ms/step - loss: 1.5794 - accuracy: 0.8824 - val_loss: 1.5811 - val_accuracy: 0.8798
# Epoch 12/300
# 94/94 [==============================] - 23s 240ms/step - loss: 1.5762 - accuracy: 0.8852 - val_loss: 1.5815 - val_accuracy: 0.8788
# Epoch 13/300
# 94/94 [==============================] - 22s 238ms/step - loss: 1.5747 - accuracy: 0.8868 - val_loss: 1.5748 - val_accuracy: 0.8862
# Epoch 14/300
# 94/94 [==============================] - 23s 240ms/step - loss: 1.5746 - accuracy: 0.8865 - val_loss: 1.5808 - val_accuracy: 0.8796
# Epoch 15/300
# 94/94 [==============================] - 23s 240ms/step - loss: 1.5719 - accuracy: 0.8898 - val_loss: 1.5759 - val_accuracy: 0.8852
# Epoch 16/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5685 - accuracy: 0.8931 - val_loss: 1.5707 - val_accuracy: 0.8903
# Epoch 17/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5672 - accuracy: 0.8939 - val_loss: 1.5739 - val_accuracy: 0.8882
# Epoch 18/300
# 94/94 [==============================] - 22s 239ms/step - loss: 1.5656 - accuracy: 0.8958 - val_loss: 1.5711 - val_accuracy: 0.8903
# Epoch 19/300
# 94/94 [==============================] - 22s 239ms/step - loss: 1.5622 - accuracy: 0.8991 - val_loss: 1.5818 - val_accuracy: 0.8792
# Epoch 20/300
# 94/94 [==============================] - 23s 240ms/step - loss: 1.5630 - accuracy: 0.8982 - val_loss: 1.5659 - val_accuracy: 0.8960
# Epoch 21/300
# 94/94 [==============================] - 23s 240ms/step - loss: 1.5599 - accuracy: 0.9016 - val_loss: 1.5645 - val_accuracy: 0.8964
# Epoch 22/300
# 94/94 [==============================] - 23s 241ms/step - loss: 1.5569 - accuracy: 0.9043 - val_loss: 1.5619 - val_accuracy: 0.8984
# Epoch 23/300
# 94/94 [==============================] - 22s 239ms/step - loss: 1.5586 - accuracy: 0.9029 - val_loss: 1.5660 - val_accuracy: 0.8946
# Epoch 24/300
# 94/94 [==============================] - 22s 238ms/step - loss: 1.5562 - accuracy: 0.9049 - val_loss: 1.5616 - val_accuracy: 0.8984
# Epoch 25/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5546 - accuracy: 0.9071 - val_loss: 1.5678 - val_accuracy: 0.8934
# Epoch 26/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5524 - accuracy: 0.9090 - val_loss: 1.5632 - val_accuracy: 0.8974
# Epoch 27/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5524 - accuracy: 0.9089 - val_loss: 1.5593 - val_accuracy: 0.9012
# Epoch 28/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5508 - accuracy: 0.9105 - val_loss: 1.5564 - val_accuracy: 0.9050
# Epoch 29/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5527 - accuracy: 0.9084 - val_loss: 1.5609 - val_accuracy: 0.8994
# Epoch 30/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5490 - accuracy: 0.9123 - val_loss: 1.5545 - val_accuracy: 0.9072
# Epoch 31/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5486 - accuracy: 0.9127 - val_loss: 1.5546 - val_accuracy: 0.9060
# Epoch 32/300
# 94/94 [==============================] - 23s 241ms/step - loss: 1.5475 - accuracy: 0.9138 - val_loss: 1.5542 - val_accuracy: 0.9078
# Epoch 33/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5473 - accuracy: 0.9139 - val_loss: 1.5527 - val_accuracy: 0.9084
# Epoch 34/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5458 - accuracy: 0.9149 - val_loss: 1.5515 - val_accuracy: 0.9092
# Epoch 35/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5457 - accuracy: 0.9153 - val_loss: 1.5564 - val_accuracy: 0.9051
# Epoch 36/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5453 - accuracy: 0.9156 - val_loss: 1.5538 - val_accuracy: 0.9077
# Epoch 37/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5437 - accuracy: 0.9171 - val_loss: 1.5544 - val_accuracy: 0.9062
# Epoch 38/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5449 - accuracy: 0.9163 - val_loss: 1.5634 - val_accuracy: 0.8975
# Epoch 39/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5439 - accuracy: 0.9170 - val_loss: 1.5576 - val_accuracy: 0.9037
# Epoch 40/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5436 - accuracy: 0.9175 - val_loss: 1.5527 - val_accuracy: 0.9084
# Epoch 41/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5422 - accuracy: 0.9193 - val_loss: 1.5536 - val_accuracy: 0.9062
# Epoch 42/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5412 - accuracy: 0.9203 - val_loss: 1.5526 - val_accuracy: 0.9088
# Epoch 43/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5410 - accuracy: 0.9202 - val_loss: 1.5550 - val_accuracy: 0.9063
# Epoch 44/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5438 - accuracy: 0.9173 - val_loss: 1.5556 - val_accuracy: 0.9054
# Epoch 45/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5394 - accuracy: 0.9216 - val_loss: 1.5570 - val_accuracy: 0.9038
# Epoch 46/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5413 - accuracy: 0.9199 - val_loss: 1.5479 - val_accuracy: 0.9132
# Epoch 47/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5383 - accuracy: 0.9229 - val_loss: 1.5504 - val_accuracy: 0.9107
# Epoch 48/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5372 - accuracy: 0.9241 - val_loss: 1.5492 - val_accuracy: 0.9118
# Epoch 49/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5384 - accuracy: 0.9228 - val_loss: 1.5512 - val_accuracy: 0.9092
# Epoch 50/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5370 - accuracy: 0.9240 - val_loss: 1.5467 - val_accuracy: 0.9144
# Epoch 51/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5373 - accuracy: 0.9238 - val_loss: 1.5496 - val_accuracy: 0.9112
# Epoch 52/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5363 - accuracy: 0.9246 - val_loss: 1.5464 - val_accuracy: 0.9143
# Epoch 53/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5380 - accuracy: 0.9229 - val_loss: 1.5532 - val_accuracy: 0.9079
# Epoch 54/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5370 - accuracy: 0.9242 - val_loss: 1.5464 - val_accuracy: 0.9148
# Epoch 55/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5356 - accuracy: 0.9252 - val_loss: 1.5488 - val_accuracy: 0.9119
# Epoch 56/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5346 - accuracy: 0.9263 - val_loss: 1.5493 - val_accuracy: 0.9113
# Epoch 57/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5348 - accuracy: 0.9263 - val_loss: 1.5455 - val_accuracy: 0.9149
# Epoch 58/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5347 - accuracy: 0.9260 - val_loss: 1.5476 - val_accuracy: 0.9137
# Epoch 59/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5337 - accuracy: 0.9274 - val_loss: 1.5486 - val_accuracy: 0.9120
# Epoch 60/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5330 - accuracy: 0.9280 - val_loss: 1.5497 - val_accuracy: 0.9116
# Epoch 61/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5323 - accuracy: 0.9287 - val_loss: 1.5464 - val_accuracy: 0.9143
# Epoch 62/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5322 - accuracy: 0.9287 - val_loss: 1.5491 - val_accuracy: 0.9122
# Epoch 63/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5321 - accuracy: 0.9293 - val_loss: 1.5424 - val_accuracy: 0.9191
# Epoch 64/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5325 - accuracy: 0.9288 - val_loss: 1.5505 - val_accuracy: 0.9106
# Epoch 65/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5327 - accuracy: 0.9284 - val_loss: 1.5462 - val_accuracy: 0.9137
# Epoch 66/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5296 - accuracy: 0.9315 - val_loss: 1.5499 - val_accuracy: 0.9113
# Epoch 67/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5332 - accuracy: 0.9275 - val_loss: 1.5514 - val_accuracy: 0.9097
# Epoch 68/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5319 - accuracy: 0.9293 - val_loss: 1.5485 - val_accuracy: 0.9125
# Epoch 69/300
# 94/94 [==============================] - 23s 249ms/step - loss: 1.5316 - accuracy: 0.9296 - val_loss: 1.5458 - val_accuracy: 0.9156
# Epoch 70/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5311 - accuracy: 0.9299 - val_loss: 1.5455 - val_accuracy: 0.9153
# Epoch 71/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5275 - accuracy: 0.9335 - val_loss: 1.5421 - val_accuracy: 0.9188
# Epoch 72/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5298 - accuracy: 0.9313 - val_loss: 1.5472 - val_accuracy: 0.9138
# Epoch 73/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5278 - accuracy: 0.9331 - val_loss: 1.5443 - val_accuracy: 0.9164
# Epoch 74/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5294 - accuracy: 0.9315 - val_loss: 1.5464 - val_accuracy: 0.9146
# Epoch 75/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5290 - accuracy: 0.9322 - val_loss: 1.5406 - val_accuracy: 0.9201
# Epoch 76/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5285 - accuracy: 0.9322 - val_loss: 1.5464 - val_accuracy: 0.9147
# Epoch 77/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5280 - accuracy: 0.9328 - val_loss: 1.5430 - val_accuracy: 0.9177
# Epoch 78/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5274 - accuracy: 0.9335 - val_loss: 1.5455 - val_accuracy: 0.9155
# Epoch 79/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5284 - accuracy: 0.9326 - val_loss: 1.5465 - val_accuracy: 0.9151
# Epoch 80/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5290 - accuracy: 0.9320 - val_loss: 1.5429 - val_accuracy: 0.9183
# Epoch 81/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5290 - accuracy: 0.9320 - val_loss: 1.5442 - val_accuracy: 0.9166
# Epoch 82/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5281 - accuracy: 0.9329 - val_loss: 1.5490 - val_accuracy: 0.9116
# Epoch 83/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5267 - accuracy: 0.9342 - val_loss: 1.5453 - val_accuracy: 0.9158
# Epoch 84/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5259 - accuracy: 0.9351 - val_loss: 1.5448 - val_accuracy: 0.9160
# Epoch 85/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5252 - accuracy: 0.9360 - val_loss: 1.5457 - val_accuracy: 0.9153
# Epoch 86/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5255 - accuracy: 0.9358 - val_loss: 1.5454 - val_accuracy: 0.9154
# Epoch 87/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5270 - accuracy: 0.9339 - val_loss: 1.5401 - val_accuracy: 0.9199
# Epoch 88/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5263 - accuracy: 0.9344 - val_loss: 1.5428 - val_accuracy: 0.9180
# Epoch 89/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5251 - accuracy: 0.9362 - val_loss: 1.5428 - val_accuracy: 0.9178
# Epoch 90/300
# 94/94 [==============================] - 23s 241ms/step - loss: 1.5236 - accuracy: 0.9375 - val_loss: 1.5452 - val_accuracy: 0.9154
# Epoch 91/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5254 - accuracy: 0.9358 - val_loss: 1.5396 - val_accuracy: 0.9221
# Epoch 92/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5227 - accuracy: 0.9384 - val_loss: 1.5423 - val_accuracy: 0.9181
# Epoch 93/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5243 - accuracy: 0.9366 - val_loss: 1.5434 - val_accuracy: 0.9174
# Epoch 94/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5238 - accuracy: 0.9371 - val_loss: 1.5486 - val_accuracy: 0.9122
# Epoch 95/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5244 - accuracy: 0.9365 - val_loss: 1.5413 - val_accuracy: 0.9191
# Epoch 96/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5231 - accuracy: 0.9379 - val_loss: 1.5450 - val_accuracy: 0.9159
# Epoch 97/300
# 94/94 [==============================] - 23s 241ms/step - loss: 1.5241 - accuracy: 0.9368 - val_loss: 1.5422 - val_accuracy: 0.9185
# Epoch 98/300
# 94/94 [==============================] - 23s 241ms/step - loss: 1.5223 - accuracy: 0.9385 - val_loss: 1.5425 - val_accuracy: 0.9177
# Epoch 99/300
# 94/94 [==============================] - 23s 241ms/step - loss: 1.5227 - accuracy: 0.9389 - val_loss: 1.5408 - val_accuracy: 0.9202
# Epoch 100/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5228 - accuracy: 0.9385 - val_loss: 1.5425 - val_accuracy: 0.9188
# Epoch 101/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5242 - accuracy: 0.9366 - val_loss: 1.5396 - val_accuracy: 0.9218
# Epoch 102/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5228 - accuracy: 0.9381 - val_loss: 1.5418 - val_accuracy: 0.9192
# Epoch 103/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5215 - accuracy: 0.9393 - val_loss: 1.5407 - val_accuracy: 0.9197
# Epoch 104/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5220 - accuracy: 0.9389 - val_loss: 1.5445 - val_accuracy: 0.9163
# Epoch 105/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5222 - accuracy: 0.9385 - val_loss: 1.5429 - val_accuracy: 0.9183
# Epoch 106/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5225 - accuracy: 0.9385 - val_loss: 1.5393 - val_accuracy: 0.9214
# Epoch 107/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5212 - accuracy: 0.9398 - val_loss: 1.5426 - val_accuracy: 0.9171
# Epoch 108/300
# 94/94 [==============================] - 23s 241ms/step - loss: 1.5237 - accuracy: 0.9372 - val_loss: 1.5444 - val_accuracy: 0.9161
# Epoch 109/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5227 - accuracy: 0.9383 - val_loss: 1.5423 - val_accuracy: 0.9181
# Epoch 110/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5205 - accuracy: 0.9407 - val_loss: 1.5374 - val_accuracy: 0.9237
# Epoch 111/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5223 - accuracy: 0.9386 - val_loss: 1.5406 - val_accuracy: 0.9197
# Epoch 112/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5198 - accuracy: 0.9413 - val_loss: 1.5405 - val_accuracy: 0.9198
# Epoch 113/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5221 - accuracy: 0.9389 - val_loss: 1.5408 - val_accuracy: 0.9196
# Epoch 114/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5209 - accuracy: 0.9401 - val_loss: 1.5380 - val_accuracy: 0.9227
# Epoch 115/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5220 - accuracy: 0.9389 - val_loss: 1.5416 - val_accuracy: 0.9194
# Epoch 116/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5206 - accuracy: 0.9407 - val_loss: 1.5472 - val_accuracy: 0.9130
# Epoch 117/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5221 - accuracy: 0.9389 - val_loss: 1.5445 - val_accuracy: 0.9164
# Epoch 118/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5202 - accuracy: 0.9409 - val_loss: 1.5389 - val_accuracy: 0.9217
# Epoch 119/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5209 - accuracy: 0.9401 - val_loss: 1.5433 - val_accuracy: 0.9177
# Epoch 120/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5211 - accuracy: 0.9398 - val_loss: 1.5409 - val_accuracy: 0.9197
# Epoch 121/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5205 - accuracy: 0.9407 - val_loss: 1.5452 - val_accuracy: 0.9156
# Epoch 122/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5210 - accuracy: 0.9396 - val_loss: 1.5403 - val_accuracy: 0.9207
# Epoch 123/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5188 - accuracy: 0.9420 - val_loss: 1.5428 - val_accuracy: 0.9183
# Epoch 124/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5174 - accuracy: 0.9434 - val_loss: 1.5391 - val_accuracy: 0.9217
# Epoch 125/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5197 - accuracy: 0.9414 - val_loss: 1.5414 - val_accuracy: 0.9197
# Epoch 126/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5193 - accuracy: 0.9418 - val_loss: 1.5405 - val_accuracy: 0.9207
# Epoch 127/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5184 - accuracy: 0.9426 - val_loss: 1.5403 - val_accuracy: 0.9207
# Epoch 128/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5168 - accuracy: 0.9443 - val_loss: 1.5368 - val_accuracy: 0.9241
# Epoch 129/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5173 - accuracy: 0.9436 - val_loss: 1.5413 - val_accuracy: 0.9194
# Epoch 130/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5160 - accuracy: 0.9449 - val_loss: 1.5387 - val_accuracy: 0.9226
# Epoch 131/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5176 - accuracy: 0.9433 - val_loss: 1.5383 - val_accuracy: 0.9221
# Epoch 132/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5192 - accuracy: 0.9417 - val_loss: 1.5404 - val_accuracy: 0.9207
# Epoch 133/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5187 - accuracy: 0.9425 - val_loss: 1.5403 - val_accuracy: 0.9205
# Epoch 134/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5178 - accuracy: 0.9435 - val_loss: 1.5386 - val_accuracy: 0.9221
# Epoch 135/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5175 - accuracy: 0.9437 - val_loss: 1.5359 - val_accuracy: 0.9249
# Epoch 136/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5154 - accuracy: 0.9456 - val_loss: 1.5383 - val_accuracy: 0.9229
# Epoch 137/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5168 - accuracy: 0.9444 - val_loss: 1.5433 - val_accuracy: 0.9179
# Epoch 138/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5166 - accuracy: 0.9443 - val_loss: 1.5373 - val_accuracy: 0.9237
# Epoch 139/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5159 - accuracy: 0.9453 - val_loss: 1.5419 - val_accuracy: 0.9195
# Epoch 140/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5150 - accuracy: 0.9461 - val_loss: 1.5355 - val_accuracy: 0.9252
# Epoch 141/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5156 - accuracy: 0.9457 - val_loss: 1.5383 - val_accuracy: 0.9222
# Epoch 142/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5176 - accuracy: 0.9435 - val_loss: 1.5447 - val_accuracy: 0.9165
# Epoch 143/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5170 - accuracy: 0.9439 - val_loss: 1.5416 - val_accuracy: 0.9197
# Epoch 144/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5164 - accuracy: 0.9448 - val_loss: 1.5399 - val_accuracy: 0.9204
# Epoch 145/300
# 94/94 [==============================] - 23s 241ms/step - loss: 1.5163 - accuracy: 0.9444 - val_loss: 1.5380 - val_accuracy: 0.9227
# Epoch 146/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5166 - accuracy: 0.9443 - val_loss: 1.5403 - val_accuracy: 0.9210
# Epoch 147/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5172 - accuracy: 0.9437 - val_loss: 1.5410 - val_accuracy: 0.9194
# Epoch 148/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5154 - accuracy: 0.9455 - val_loss: 1.5403 - val_accuracy: 0.9201
# Epoch 149/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5166 - accuracy: 0.9443 - val_loss: 1.5407 - val_accuracy: 0.9203
# Epoch 150/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5171 - accuracy: 0.9440 - val_loss: 1.5366 - val_accuracy: 0.9243
# Epoch 151/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5159 - accuracy: 0.9451 - val_loss: 1.5371 - val_accuracy: 0.9238
# Epoch 152/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5149 - accuracy: 0.9459 - val_loss: 1.5413 - val_accuracy: 0.9195
# Epoch 153/300
# 94/94 [==============================] - 23s 241ms/step - loss: 1.5156 - accuracy: 0.9453 - val_loss: 1.5378 - val_accuracy: 0.9228
# Epoch 154/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5156 - accuracy: 0.9451 - val_loss: 1.5369 - val_accuracy: 0.9242
# Epoch 155/300
# 94/94 [==============================] - 23s 240ms/step - loss: 1.5152 - accuracy: 0.9458 - val_loss: 1.5365 - val_accuracy: 0.9250
# Epoch 156/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5156 - accuracy: 0.9453 - val_loss: 1.5406 - val_accuracy: 0.9198
# Epoch 157/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5135 - accuracy: 0.9474 - val_loss: 1.5416 - val_accuracy: 0.9190
# Epoch 158/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5145 - accuracy: 0.9463 - val_loss: 1.5406 - val_accuracy: 0.9202
# Epoch 159/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5132 - accuracy: 0.9479 - val_loss: 1.5378 - val_accuracy: 0.9235
# Epoch 160/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5153 - accuracy: 0.9459 - val_loss: 1.5391 - val_accuracy: 0.9215
# Epoch 161/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5139 - accuracy: 0.9470 - val_loss: 1.5356 - val_accuracy: 0.9258
# Epoch 162/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5132 - accuracy: 0.9478 - val_loss: 1.5366 - val_accuracy: 0.9244
# Epoch 163/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5137 - accuracy: 0.9473 - val_loss: 1.5357 - val_accuracy: 0.9254
# Epoch 164/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5149 - accuracy: 0.9461 - val_loss: 1.5419 - val_accuracy: 0.9188
# Epoch 165/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5136 - accuracy: 0.9474 - val_loss: 1.5440 - val_accuracy: 0.9162
# Epoch 166/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5136 - accuracy: 0.9474 - val_loss: 1.5405 - val_accuracy: 0.9209
# Epoch 167/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5141 - accuracy: 0.9471 - val_loss: 1.5374 - val_accuracy: 0.9238
# Epoch 168/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5147 - accuracy: 0.9464 - val_loss: 1.5403 - val_accuracy: 0.9206
# Epoch 169/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5136 - accuracy: 0.9476 - val_loss: 1.5392 - val_accuracy: 0.9212
# Epoch 170/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5144 - accuracy: 0.9465 - val_loss: 1.5363 - val_accuracy: 0.9247
# Epoch 171/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5134 - accuracy: 0.9474 - val_loss: 1.5408 - val_accuracy: 0.9202
# Epoch 172/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5142 - accuracy: 0.9463 - val_loss: 1.5388 - val_accuracy: 0.9222
# Epoch 173/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5125 - accuracy: 0.9485 - val_loss: 1.5413 - val_accuracy: 0.9197
# Epoch 174/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5124 - accuracy: 0.9485 - val_loss: 1.5411 - val_accuracy: 0.9195
# Epoch 175/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5127 - accuracy: 0.9485 - val_loss: 1.5414 - val_accuracy: 0.9192
# Epoch 176/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5126 - accuracy: 0.9481 - val_loss: 1.5440 - val_accuracy: 0.9169
# Epoch 177/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5138 - accuracy: 0.9473 - val_loss: 1.5394 - val_accuracy: 0.9212
# Epoch 178/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5128 - accuracy: 0.9481 - val_loss: 1.5381 - val_accuracy: 0.9229
# Epoch 179/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5139 - accuracy: 0.9472 - val_loss: 1.5379 - val_accuracy: 0.9232
# Epoch 180/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5117 - accuracy: 0.9494 - val_loss: 1.5396 - val_accuracy: 0.9215
# Epoch 181/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5116 - accuracy: 0.9495 - val_loss: 1.5409 - val_accuracy: 0.9201
# Epoch 182/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5139 - accuracy: 0.9473 - val_loss: 1.5400 - val_accuracy: 0.9208
# Epoch 183/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5129 - accuracy: 0.9480 - val_loss: 1.5353 - val_accuracy: 0.9261
# Epoch 184/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5101 - accuracy: 0.9510 - val_loss: 1.5379 - val_accuracy: 0.9232
# Epoch 185/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5114 - accuracy: 0.9497 - val_loss: 1.5392 - val_accuracy: 0.9217
# Epoch 186/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5143 - accuracy: 0.9468 - val_loss: 1.5413 - val_accuracy: 0.9194
# Epoch 187/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5114 - accuracy: 0.9494 - val_loss: 1.5381 - val_accuracy: 0.9230
# Epoch 188/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5116 - accuracy: 0.9491 - val_loss: 1.5385 - val_accuracy: 0.9222
# Epoch 189/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5123 - accuracy: 0.9486 - val_loss: 1.5419 - val_accuracy: 0.9187
# Epoch 190/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5120 - accuracy: 0.9490 - val_loss: 1.5416 - val_accuracy: 0.9196
# Epoch 191/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5117 - accuracy: 0.9492 - val_loss: 1.5408 - val_accuracy: 0.9200
# Epoch 192/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5141 - accuracy: 0.9467 - val_loss: 1.5381 - val_accuracy: 0.9228
# Epoch 193/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5112 - accuracy: 0.9499 - val_loss: 1.5396 - val_accuracy: 0.9219
# Epoch 194/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5132 - accuracy: 0.9480 - val_loss: 1.5380 - val_accuracy: 0.9228
# Epoch 195/300
# 94/94 [==============================] - 23s 241ms/step - loss: 1.5112 - accuracy: 0.9500 - val_loss: 1.5387 - val_accuracy: 0.9222
# Epoch 196/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5113 - accuracy: 0.9496 - val_loss: 1.5375 - val_accuracy: 0.9234
# Epoch 197/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5123 - accuracy: 0.9486 - val_loss: 1.5363 - val_accuracy: 0.9245
# Epoch 198/300
# 94/94 [==============================] - 22s 239ms/step - loss: 1.5103 - accuracy: 0.9509 - val_loss: 1.5362 - val_accuracy: 0.9246
# Epoch 199/300
# 94/94 [==============================] - 23s 241ms/step - loss: 1.5116 - accuracy: 0.9495 - val_loss: 1.5390 - val_accuracy: 0.9220
# Epoch 200/300
# 94/94 [==============================] - 23s 239ms/step - loss: 1.5118 - accuracy: 0.9492 - val_loss: 1.5382 - val_accuracy: 0.9222
# Epoch 201/300
# 94/94 [==============================] - 23s 240ms/step - loss: 1.5104 - accuracy: 0.9510 - val_loss: 1.5364 - val_accuracy: 0.9243
# Epoch 202/300
# 94/94 [==============================] - 23s 240ms/step - loss: 1.5126 - accuracy: 0.9485 - val_loss: 1.5402 - val_accuracy: 0.9208
# Epoch 203/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5108 - accuracy: 0.9504 - val_loss: 1.5389 - val_accuracy: 0.9216
# Epoch 204/300
# 94/94 [==============================] - 22s 238ms/step - loss: 1.5106 - accuracy: 0.9502 - val_loss: 1.5384 - val_accuracy: 0.9225
# Epoch 205/300
# 94/94 [==============================] - 23s 239ms/step - loss: 1.5099 - accuracy: 0.9512 - val_loss: 1.5396 - val_accuracy: 0.9219
# Epoch 206/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5091 - accuracy: 0.9516 - val_loss: 1.5380 - val_accuracy: 0.9232
# Epoch 207/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5104 - accuracy: 0.9506 - val_loss: 1.5380 - val_accuracy: 0.9235
# Epoch 208/300
# 94/94 [==============================] - ETA: 0s - loss: 1.5115 - accuracy: 0.9494Restoring model weights from the end of the best epoch.
# 94/94 [==============================] - 23s 241ms/step - loss: 1.5115 - accuracy: 0.9494 - val_loss: 1.5392 - val_accuracy: 0.9222
# Epoch 00208: early stopping

# %%
plt.figure(3)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')

# %% [markdown]
# **Testing Accuracy**

# %%
test_loss, test_acc = model.evaluate(test_images_n,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 1.5318 - accuracy: 0.9288
#
# Test accuracy: 0.9287999868392944

# %% [markdown]
# **Error Analysis and Future Improvements**

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels,np.argmax(model.predict(test_images_n),axis=1))

true_labels = [labels_text[x] for x in test_labels]
predicted_labels = [labels_text[x] for x in np.argmax(model.predict(test_images_n),axis=1)]

import seaborn as sns
plt.figure(figsize=(8,6))
sns.heatmap(cm, xticklabels=labels_text, yticklabels=labels_text, cmap='binary',annot=True)
plt.ylabel('true')
plt.xlabel('pred')
# Out:
# Text(0.5, 33.0, 'pred')

# %% [markdown]
# The most common error is to mistake a shirt for a top and vice versa, and most errors are symmetrical. However, a perculiar one way error is to mistake a ankle-boot for a sneaker. Let's check out some images for the errors.

# %%
labels_text
# Out:
# ['T-Shirt/Top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
ind = list(set(np.where(np.array(true_labels)=="Ankle boot")[0].tolist()).intersection(np.where(np.array(predicted_labels)=="Sneaker")[0].tolist()))
plt.figure(figsize=(25,5))
for i in range(0,5):
  plt.subplot(1,5,i+1)
  plt.imshow(test_images[ind[i]])
  plt.title("Ankle Boot but pred Sneaker")


ind = list(set(np.where(np.array(true_labels)=="Shirt")[0].tolist()).intersection(np.where(np.array(predicted_labels)=="T-Shirt/Top")[0].tolist()))
plt.figure(figsize=(25,5))
for i in range(0,5):
  plt.subplot(1,5,i+1)
  plt.imshow(test_images[ind[i]])
  plt.title("Shirt but pred T-Shirt/Top")


ind = list(set(np.where(np.array(true_labels)=="Pullover")[0].tolist()).intersection(np.where(np.array(predicted_labels)=="Coat")[0].tolist()))
plt.figure(figsize=(25,5))
for i in range(0,5):
  plt.subplot(1,5,i+1)
  plt.imshow(test_images[ind[i]])
  plt.title("Pullover but pred Coat")

# %% [markdown]
# *    Some of these error pictures are really ambigous, not sure if a human will also classify it correctly.
#
# *    Seems like the pictures in the test set are also focused nicely. In this case the image augmentation might add addtional noise that might distort the accuracy of the model, and might not be worth it to perform augmentation since it adds additional processing and training time. Some other augmentation methods could be tried out like random erasing of pixels. But the augmentation parameters will have carefully tuned to ensure there is minimal noise within the training data.
#
# *    For future models, bayesian opt can be used to find the better hyperparameters that includes the number of filters, size of the the filters, dropout ratio and number of neurouns in the dense layer.
#
# *    Also deeper convolutional networks architectures like ResNet with skip connections could be used to pick out more advanced features of classification.
#
# *    Hyperparameters optimization and increasing the depth of the network can have diminishing returns on the accuracy vs training complexity.

# %% [markdown]
# **Testing effect for only a Maxpooling layer instead**

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, AveragePooling2D, Concatenate, BatchNormalization, Dropout
from keras.callbacks import EarlyStopping

input_layera = keras.Input(shape=(28,28,1))
bna = BatchNormalization()(input_layera)                                          #batch normalization to prevent the network from being fixated on a certain feature, by keeping the weights of the network from going too extreme
conv1a = Conv2D(filters=128,kernel_size=3,activation='relu')(bna)                 #large number of initial (3x3) filter to gather features for the model
do_1a = keras.layers.Dropout(0.1)(conv1a)                                         #dropout between image layers to prevent overfitting to the training dataset
conv2a = Conv2D(filters=64,kernel_size=3,activation='relu')(do_1a)                #second layer of filter to obtain higher level features
mp1a = MaxPooling2D(pool_size=(3,3))(conv2a)                                      # maxpooling only
flat1a = Flatten()(mp1a)                                                         #convert output of filters into single feature vector
do_2a = keras.layers.Dropout(0.1)(flat1a)                                         #again dropout to prevent overfitting
dense1a = Dense(128,activation='relu')(do_2a)
bn2a = BatchNormalization()(dense1a)                                             #dense layer to evaluate the feature vector and obtain accurate feature representation
output_layera = Dense(10, activation='softmax')(bn2a)                          #softmax for output for catergorical classification

model2 = keras.Model(inputs=input_layera, outputs=output_layera)
model2.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 28, 1)         4
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 26, 26, 128)       1280
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 64)        73792
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               524416
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 601,294
# Trainable params: 601,036
# Non-trainable params: 258
# _________________________________________________________________

# %%
model2.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
### using early stopping to stop the training once the validation accuracy plateau, to ensure that the model will not be overfitting, 
es = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=25, restore_best_weights=True)
history = model2.fit(train_generator,validation_data=val_generator, epochs=300, callbacks=[es], batch_size=512, shuffle=True)
# Out:
# Epoch 1/300
# 94/94 [==============================] - 24s 250ms/step - loss: 1.7180 - accuracy: 0.7597 - val_loss: 2.1853 - val_accuracy: 0.3638
# Epoch 2/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.6209 - accuracy: 0.8501 - val_loss: 1.9464 - val_accuracy: 0.6655
# Epoch 3/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5973 - accuracy: 0.8708 - val_loss: 1.7467 - val_accuracy: 0.7948
# Epoch 4/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5864 - accuracy: 0.8809 - val_loss: 1.6088 - val_accuracy: 0.8712
# Epoch 5/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5797 - accuracy: 0.8868 - val_loss: 1.5802 - val_accuracy: 0.8881
# Epoch 6/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5749 - accuracy: 0.8904 - val_loss: 1.5768 - val_accuracy: 0.8868
# Epoch 7/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5688 - accuracy: 0.8963 - val_loss: 1.5734 - val_accuracy: 0.8922
# Epoch 8/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5647 - accuracy: 0.9006 - val_loss: 1.5681 - val_accuracy: 0.8954
# Epoch 9/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5604 - accuracy: 0.9042 - val_loss: 1.5715 - val_accuracy: 0.8909
# Epoch 10/300
# 94/94 [==============================] - 23s 248ms/step - loss: 1.5579 - accuracy: 0.9075 - val_loss: 1.5614 - val_accuracy: 0.9041
# Epoch 11/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5555 - accuracy: 0.9091 - val_loss: 1.5650 - val_accuracy: 0.8985
# Epoch 12/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5538 - accuracy: 0.9099 - val_loss: 1.5613 - val_accuracy: 0.9019
# Epoch 13/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5515 - accuracy: 0.9129 - val_loss: 1.5635 - val_accuracy: 0.8991
# Epoch 14/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5499 - accuracy: 0.9144 - val_loss: 1.5561 - val_accuracy: 0.9048
# Epoch 15/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5474 - accuracy: 0.9160 - val_loss: 1.5552 - val_accuracy: 0.9088
# Epoch 16/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5467 - accuracy: 0.9164 - val_loss: 1.5570 - val_accuracy: 0.9057
# Epoch 17/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5452 - accuracy: 0.9182 - val_loss: 1.5582 - val_accuracy: 0.9038
# Epoch 18/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5436 - accuracy: 0.9198 - val_loss: 1.5531 - val_accuracy: 0.9104
# Epoch 19/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5415 - accuracy: 0.9215 - val_loss: 1.5574 - val_accuracy: 0.9061
# Epoch 20/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5407 - accuracy: 0.9231 - val_loss: 1.5508 - val_accuracy: 0.9122
# Epoch 21/300
# 94/94 [==============================] - 23s 248ms/step - loss: 1.5412 - accuracy: 0.9218 - val_loss: 1.5541 - val_accuracy: 0.9075
# Epoch 22/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5402 - accuracy: 0.9232 - val_loss: 1.5464 - val_accuracy: 0.9175
# Epoch 23/300
# 94/94 [==============================] - 23s 248ms/step - loss: 1.5390 - accuracy: 0.9240 - val_loss: 1.5558 - val_accuracy: 0.9048
# Epoch 24/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5379 - accuracy: 0.9253 - val_loss: 1.5488 - val_accuracy: 0.9146
# Epoch 25/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5369 - accuracy: 0.9262 - val_loss: 1.5517 - val_accuracy: 0.9112
# Epoch 26/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5366 - accuracy: 0.9265 - val_loss: 1.5519 - val_accuracy: 0.9113
# Epoch 27/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5364 - accuracy: 0.9261 - val_loss: 1.5461 - val_accuracy: 0.9173
# Epoch 28/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5325 - accuracy: 0.9309 - val_loss: 1.5452 - val_accuracy: 0.9168
# Epoch 29/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5347 - accuracy: 0.9284 - val_loss: 1.5495 - val_accuracy: 0.9126
# Epoch 30/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5336 - accuracy: 0.9290 - val_loss: 1.5563 - val_accuracy: 0.9057
# Epoch 31/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5313 - accuracy: 0.9319 - val_loss: 1.5436 - val_accuracy: 0.9182
# Epoch 32/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5307 - accuracy: 0.9321 - val_loss: 1.5508 - val_accuracy: 0.9113
# Epoch 33/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5318 - accuracy: 0.9310 - val_loss: 1.5449 - val_accuracy: 0.9178
# Epoch 34/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5308 - accuracy: 0.9323 - val_loss: 1.5488 - val_accuracy: 0.9125
# Epoch 35/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5289 - accuracy: 0.9338 - val_loss: 1.5448 - val_accuracy: 0.9183
# Epoch 36/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5285 - accuracy: 0.9344 - val_loss: 1.5416 - val_accuracy: 0.9202
# Epoch 37/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5277 - accuracy: 0.9360 - val_loss: 1.5455 - val_accuracy: 0.9172
# Epoch 38/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5271 - accuracy: 0.9356 - val_loss: 1.5404 - val_accuracy: 0.9218
# Epoch 39/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5269 - accuracy: 0.9357 - val_loss: 1.5413 - val_accuracy: 0.9216
# Epoch 40/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5264 - accuracy: 0.9364 - val_loss: 1.5402 - val_accuracy: 0.9212
# Epoch 41/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5249 - accuracy: 0.9377 - val_loss: 1.5440 - val_accuracy: 0.9181
# Epoch 42/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5258 - accuracy: 0.9369 - val_loss: 1.5436 - val_accuracy: 0.9187
# Epoch 43/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5266 - accuracy: 0.9359 - val_loss: 1.5469 - val_accuracy: 0.9141
# Epoch 44/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5245 - accuracy: 0.9381 - val_loss: 1.5472 - val_accuracy: 0.9145
# Epoch 45/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5242 - accuracy: 0.9387 - val_loss: 1.5571 - val_accuracy: 0.9044
# Epoch 46/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5249 - accuracy: 0.9377 - val_loss: 1.5408 - val_accuracy: 0.9218
# Epoch 47/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5217 - accuracy: 0.9408 - val_loss: 1.5401 - val_accuracy: 0.9221
# Epoch 48/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5220 - accuracy: 0.9407 - val_loss: 1.5466 - val_accuracy: 0.9149
# Epoch 49/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5226 - accuracy: 0.9398 - val_loss: 1.5422 - val_accuracy: 0.9204
# Epoch 50/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5225 - accuracy: 0.9401 - val_loss: 1.5397 - val_accuracy: 0.9222
# Epoch 51/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5230 - accuracy: 0.9394 - val_loss: 1.5419 - val_accuracy: 0.9201
# Epoch 52/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5200 - accuracy: 0.9425 - val_loss: 1.5385 - val_accuracy: 0.9230
# Epoch 53/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5214 - accuracy: 0.9411 - val_loss: 1.5417 - val_accuracy: 0.9204
# Epoch 54/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5210 - accuracy: 0.9409 - val_loss: 1.5445 - val_accuracy: 0.9173
# Epoch 55/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5201 - accuracy: 0.9427 - val_loss: 1.5374 - val_accuracy: 0.9251
# Epoch 56/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5189 - accuracy: 0.9435 - val_loss: 1.5391 - val_accuracy: 0.9227
# Epoch 57/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5190 - accuracy: 0.9435 - val_loss: 1.5382 - val_accuracy: 0.9225
# Epoch 58/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5186 - accuracy: 0.9439 - val_loss: 1.5411 - val_accuracy: 0.9199
# Epoch 59/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5185 - accuracy: 0.9440 - val_loss: 1.5386 - val_accuracy: 0.9238
# Epoch 60/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5182 - accuracy: 0.9445 - val_loss: 1.5375 - val_accuracy: 0.9245
# Epoch 61/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5179 - accuracy: 0.9445 - val_loss: 1.5395 - val_accuracy: 0.9223
# Epoch 62/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5181 - accuracy: 0.9435 - val_loss: 1.5383 - val_accuracy: 0.9234
# Epoch 63/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5192 - accuracy: 0.9429 - val_loss: 1.5377 - val_accuracy: 0.9236
# Epoch 64/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5163 - accuracy: 0.9463 - val_loss: 1.5375 - val_accuracy: 0.9246
# Epoch 65/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5169 - accuracy: 0.9454 - val_loss: 1.5367 - val_accuracy: 0.9246
# Epoch 66/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5162 - accuracy: 0.9463 - val_loss: 1.5378 - val_accuracy: 0.9232
# Epoch 67/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5170 - accuracy: 0.9451 - val_loss: 1.5406 - val_accuracy: 0.9208
# Epoch 68/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5154 - accuracy: 0.9468 - val_loss: 1.5395 - val_accuracy: 0.9222
# Epoch 69/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5159 - accuracy: 0.9469 - val_loss: 1.5382 - val_accuracy: 0.9227
# Epoch 70/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5138 - accuracy: 0.9486 - val_loss: 1.5381 - val_accuracy: 0.9227
# Epoch 71/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5148 - accuracy: 0.9474 - val_loss: 1.5373 - val_accuracy: 0.9237
# Epoch 72/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5142 - accuracy: 0.9481 - val_loss: 1.5422 - val_accuracy: 0.9196
# Epoch 73/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5149 - accuracy: 0.9476 - val_loss: 1.5351 - val_accuracy: 0.9258
# Epoch 74/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5148 - accuracy: 0.9475 - val_loss: 1.5443 - val_accuracy: 0.9170
# Epoch 75/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5143 - accuracy: 0.9478 - val_loss: 1.5352 - val_accuracy: 0.9259
# Epoch 76/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5139 - accuracy: 0.9482 - val_loss: 1.5383 - val_accuracy: 0.9231
# Epoch 77/300
# 94/94 [==============================] - 23s 248ms/step - loss: 1.5132 - accuracy: 0.9490 - val_loss: 1.5376 - val_accuracy: 0.9239
# Epoch 78/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5127 - accuracy: 0.9492 - val_loss: 1.5399 - val_accuracy: 0.9203
# Epoch 79/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5117 - accuracy: 0.9508 - val_loss: 1.5429 - val_accuracy: 0.9196
# Epoch 80/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5144 - accuracy: 0.9481 - val_loss: 1.5359 - val_accuracy: 0.9252
# Epoch 81/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5120 - accuracy: 0.9505 - val_loss: 1.5376 - val_accuracy: 0.9241
# Epoch 82/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5116 - accuracy: 0.9511 - val_loss: 1.5365 - val_accuracy: 0.9258
# Epoch 83/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5116 - accuracy: 0.9503 - val_loss: 1.5333 - val_accuracy: 0.9287
# Epoch 84/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5117 - accuracy: 0.9499 - val_loss: 1.5366 - val_accuracy: 0.9244
# Epoch 85/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5111 - accuracy: 0.9508 - val_loss: 1.5358 - val_accuracy: 0.9255
# Epoch 86/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5110 - accuracy: 0.9513 - val_loss: 1.5350 - val_accuracy: 0.9260
# Epoch 87/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5105 - accuracy: 0.9518 - val_loss: 1.5338 - val_accuracy: 0.9285
# Epoch 88/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5112 - accuracy: 0.9508 - val_loss: 1.5355 - val_accuracy: 0.9262
# Epoch 89/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5117 - accuracy: 0.9504 - val_loss: 1.5342 - val_accuracy: 0.9267
# Epoch 90/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5102 - accuracy: 0.9515 - val_loss: 1.5364 - val_accuracy: 0.9258
# Epoch 91/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5106 - accuracy: 0.9514 - val_loss: 1.5362 - val_accuracy: 0.9251
# Epoch 92/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5096 - accuracy: 0.9527 - val_loss: 1.5345 - val_accuracy: 0.9268
# Epoch 93/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5111 - accuracy: 0.9510 - val_loss: 1.5347 - val_accuracy: 0.9277
# Epoch 94/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5088 - accuracy: 0.9535 - val_loss: 1.5348 - val_accuracy: 0.9267
# Epoch 95/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5082 - accuracy: 0.9542 - val_loss: 1.5356 - val_accuracy: 0.9264
# Epoch 96/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5091 - accuracy: 0.9529 - val_loss: 1.5365 - val_accuracy: 0.9256
# Epoch 97/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5090 - accuracy: 0.9531 - val_loss: 1.5357 - val_accuracy: 0.9256
# Epoch 98/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5093 - accuracy: 0.9526 - val_loss: 1.5346 - val_accuracy: 0.9262
# Epoch 99/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5077 - accuracy: 0.9546 - val_loss: 1.5377 - val_accuracy: 0.9240
# Epoch 100/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5077 - accuracy: 0.9545 - val_loss: 1.5308 - val_accuracy: 0.9307
# Epoch 101/300
# 94/94 [==============================] - 23s 248ms/step - loss: 1.5079 - accuracy: 0.9540 - val_loss: 1.5357 - val_accuracy: 0.9255
# Epoch 102/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5069 - accuracy: 0.9548 - val_loss: 1.5319 - val_accuracy: 0.9288
# Epoch 103/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5068 - accuracy: 0.9551 - val_loss: 1.5310 - val_accuracy: 0.9312
# Epoch 104/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5057 - accuracy: 0.9564 - val_loss: 1.5337 - val_accuracy: 0.9275
# Epoch 105/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5069 - accuracy: 0.9550 - val_loss: 1.5358 - val_accuracy: 0.9249
# Epoch 106/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5076 - accuracy: 0.9544 - val_loss: 1.5342 - val_accuracy: 0.9268
# Epoch 107/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5051 - accuracy: 0.9573 - val_loss: 1.5347 - val_accuracy: 0.9268
# Epoch 108/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.5063 - accuracy: 0.9555 - val_loss: 1.5329 - val_accuracy: 0.9292
# Epoch 109/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5070 - accuracy: 0.9546 - val_loss: 1.5339 - val_accuracy: 0.9276
# Epoch 110/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5065 - accuracy: 0.9556 - val_loss: 1.5318 - val_accuracy: 0.9295
# Epoch 111/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5062 - accuracy: 0.9562 - val_loss: 1.5300 - val_accuracy: 0.9308
# Epoch 112/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5051 - accuracy: 0.9571 - val_loss: 1.5316 - val_accuracy: 0.9297
# Epoch 113/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5058 - accuracy: 0.9562 - val_loss: 1.5322 - val_accuracy: 0.9296
# Epoch 114/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5063 - accuracy: 0.9555 - val_loss: 1.5342 - val_accuracy: 0.9274
# Epoch 115/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5053 - accuracy: 0.9570 - val_loss: 1.5345 - val_accuracy: 0.9264
# Epoch 116/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5044 - accuracy: 0.9576 - val_loss: 1.5333 - val_accuracy: 0.9269
# Epoch 117/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5047 - accuracy: 0.9574 - val_loss: 1.5358 - val_accuracy: 0.9257
# Epoch 118/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5047 - accuracy: 0.9573 - val_loss: 1.5330 - val_accuracy: 0.9278
# Epoch 119/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5045 - accuracy: 0.9574 - val_loss: 1.5301 - val_accuracy: 0.9314
# Epoch 120/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5047 - accuracy: 0.9573 - val_loss: 1.5370 - val_accuracy: 0.9235
# Epoch 121/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5043 - accuracy: 0.9577 - val_loss: 1.5306 - val_accuracy: 0.9305
# Epoch 122/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5050 - accuracy: 0.9568 - val_loss: 1.5366 - val_accuracy: 0.9243
# Epoch 123/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5047 - accuracy: 0.9567 - val_loss: 1.5314 - val_accuracy: 0.9298
# Epoch 124/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5028 - accuracy: 0.9590 - val_loss: 1.5349 - val_accuracy: 0.9262
# Epoch 125/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5046 - accuracy: 0.9574 - val_loss: 1.5336 - val_accuracy: 0.9273
# Epoch 126/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5042 - accuracy: 0.9577 - val_loss: 1.5388 - val_accuracy: 0.9218
# Epoch 127/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5027 - accuracy: 0.9590 - val_loss: 1.5330 - val_accuracy: 0.9287
# Epoch 128/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5019 - accuracy: 0.9599 - val_loss: 1.5350 - val_accuracy: 0.9262
# Epoch 129/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5023 - accuracy: 0.9600 - val_loss: 1.5327 - val_accuracy: 0.9282
# Epoch 130/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5022 - accuracy: 0.9593 - val_loss: 1.5312 - val_accuracy: 0.9314
# Epoch 131/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5022 - accuracy: 0.9599 - val_loss: 1.5306 - val_accuracy: 0.9309
# Epoch 132/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5030 - accuracy: 0.9585 - val_loss: 1.5330 - val_accuracy: 0.9281
# Epoch 133/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5021 - accuracy: 0.9600 - val_loss: 1.5299 - val_accuracy: 0.9323
# Epoch 134/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5018 - accuracy: 0.9600 - val_loss: 1.5335 - val_accuracy: 0.9277
# Epoch 135/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5018 - accuracy: 0.9603 - val_loss: 1.5350 - val_accuracy: 0.9254
# Epoch 136/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5014 - accuracy: 0.9607 - val_loss: 1.5384 - val_accuracy: 0.9226
# Epoch 137/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5024 - accuracy: 0.9595 - val_loss: 1.5304 - val_accuracy: 0.9313
# Epoch 138/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5022 - accuracy: 0.9598 - val_loss: 1.5319 - val_accuracy: 0.9290
# Epoch 139/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5013 - accuracy: 0.9603 - val_loss: 1.5328 - val_accuracy: 0.9291
# Epoch 140/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5032 - accuracy: 0.9585 - val_loss: 1.5334 - val_accuracy: 0.9283
# Epoch 141/300
# 94/94 [==============================] - 23s 248ms/step - loss: 1.5010 - accuracy: 0.9610 - val_loss: 1.5327 - val_accuracy: 0.9288
# Epoch 142/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5017 - accuracy: 0.9597 - val_loss: 1.5313 - val_accuracy: 0.9302
# Epoch 143/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5009 - accuracy: 0.9609 - val_loss: 1.5316 - val_accuracy: 0.9305
# Epoch 144/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5015 - accuracy: 0.9604 - val_loss: 1.5311 - val_accuracy: 0.9303
# Epoch 145/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.5009 - accuracy: 0.9609 - val_loss: 1.5297 - val_accuracy: 0.9312
# Epoch 146/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.5003 - accuracy: 0.9617 - val_loss: 1.5312 - val_accuracy: 0.9303
# Epoch 147/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5010 - accuracy: 0.9606 - val_loss: 1.5307 - val_accuracy: 0.9297
# Epoch 148/300
# 94/94 [==============================] - 23s 246ms/step - loss: 1.4999 - accuracy: 0.9619 - val_loss: 1.5329 - val_accuracy: 0.9281
# Epoch 149/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.4998 - accuracy: 0.9620 - val_loss: 1.5337 - val_accuracy: 0.9275
# Epoch 150/300
# 94/94 [==============================] - 23s 247ms/step - loss: 1.5005 - accuracy: 0.9613 - val_loss: 1.5317 - val_accuracy: 0.9298
# Epoch 151/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.4999 - accuracy: 0.9622 - val_loss: 1.5289 - val_accuracy: 0.9321
# Epoch 152/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5000 - accuracy: 0.9619 - val_loss: 1.5363 - val_accuracy: 0.9246
# Epoch 153/300
# 94/94 [==============================] - 23s 242ms/step - loss: 1.4996 - accuracy: 0.9622 - val_loss: 1.5302 - val_accuracy: 0.9313
# Epoch 154/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.5000 - accuracy: 0.9618 - val_loss: 1.5356 - val_accuracy: 0.9260
# Epoch 155/300
# 94/94 [==============================] - 23s 244ms/step - loss: 1.4995 - accuracy: 0.9623 - val_loss: 1.5312 - val_accuracy: 0.9304
# Epoch 156/300
# 94/94 [==============================] - 23s 243ms/step - loss: 1.5002 - accuracy: 0.9617 - val_loss: 1.5306 - val_accuracy: 0.9311
# Epoch 157/300
# 94/94 [==============================] - 23s 245ms/step - loss: 1.4995 - accuracy: 0.9624 - val_loss: 1.5316 - val_accuracy: 0.9300
# Epoch 158/300
# 94/94 [==============================] - ETA: 0s - loss: 1.4999 - accuracy: 0.9620Restoring model weights from the end of the best epoch.
# 94/94 [==============================] - 23s 244ms/step - loss: 1.4999 - accuracy: 0.9620 - val_loss: 1.5308 - val_accuracy: 0.9315
# Epoch 00158: early stopping

# %%
test_loss, test_acc = model2.evaluate(test_images_n,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 1.5295 - accuracy: 0.9312
#
# Test accuracy: 0.9312000274658203

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels,np.argmax(model2.predict(test_images_n),axis=1))

import seaborn as sns
plt.figure(figsize=(8,6))
sns.heatmap(cm, xticklabels=labels_text, yticklabels=labels_text, cmap='binary',annot=True)
plt.ylabel('true')
plt.xlabel('pred')
# Out:
# Text(0.5, 33.0, 'pred')
